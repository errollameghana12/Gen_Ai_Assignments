# %%
# First, make sure langchain and langchain-core are properly installed
# !pip install langchain langchain-core

# Wait a moment for installation to complete
import time
time.sleep(5)

# Use the updated import paths for newer versions of langchain
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate

# Now you can use these classes as needed
# Example:
# template = PromptTemplate.from_template("Hello, {name}!")
# chat_template = ChatPromptTemplate.from_messages([("human", "Hi, I'm {name}")])
# Out:
# Requirement already satisfied: langchain in c:\users\errol\anaconda3\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in c:\users\errol\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\errol\anaconda3\lib\site-packages (from langchain) (1.1.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\errol\anaconda3\lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\errol\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\errol\anaconda3\lib\site-packages (from langchain-core) (0.7.34)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\errol\anaconda3\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\errol\anaconda3\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\errol\anaconda3\lib\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\errol\anaconda3\lib\site-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\errol\anaconda3\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\errol\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\errol\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\errol\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\errol\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\errol\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\errol\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\errol\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\errol\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\errol\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\errol\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\errol\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in c:\users\errol\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.7.0)
# Requirement already satisfied: certifi in c:\users\errol\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\errol\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\errol\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\errol\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\errol\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\errol\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\errol\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\errol\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\errol\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)

# %%
# Correct import for latest LangChain
from langchain_core.prompts import PromptTemplate

template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

print(template_1.format(topic="Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %%
# Task 2: Multi-Input Prompt System

template_2 = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

print(template_2.format(topic="AI", audience="beginners", tone="friendly"))
print(template_2.format(topic="Python", audience="kids", tone="fun"))
print(template_2.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %%
# Task 3: Prompt Variations

teaching = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching.format(topic=topic))
print(interview.format(topic=topic))
print(story.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %%
# Task 2: Multi-Input Prompt System

from langchain_core.prompts import PromptTemplate

template_2 = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

print(template_2.format(topic="AI", audience="beginners", tone="friendly"))
print(template_2.format(topic="Python", audience="kids", tone="fun"))
print(template_2.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %%
# Task 3: Prompt Variations Engine

from langchain_core.prompts import PromptTemplate

teaching = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching.format(topic=topic))
print(interview.format(topic=topic))
print(story.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %%
# Task 4: ChatPromptTemplate System

from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {role}"),
    ("user", "Explain {topic}")
])

print(chat_template.format(role="teacher", topic="Neural Networks"))
print(chat_template.format(role="interviewer", topic="Neural Networks"))
print(chat_template.format(role="motivator", topic="Neural Networks"))
# Out:
# System: You are a teacher
# Human: Explain Neural Networks
# System: You are a interviewer
# Human: Explain Neural Networks
# System: You are a motivator
# Human: Explain Neural Networks

# %%
# Task 5: Input Validation Layer

def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        audience = "beginner"

    if tone not in valid_tone:
        tone = "formal"

    return audience, tone


print(validate_inputs("kids", "fun"))
print(validate_inputs("expert", "casual"))
# Out:
# ('beginner', 'fun')
# ('expert', 'casual')

# %%
# Task 6: Prompt Generator

from langchain_core.prompts import PromptTemplate

def generate_prompt(topic, audience, tone, style):
    audience, tone = validate_inputs(audience, tone)

    templates = {
        "teaching": PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} teaching style"
        ),
        "interview": PromptTemplate(
            input_variables=["topic"],
            template="Ask 3 interview questions about {topic}"
        ),
        "storytelling": PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} storytelling style"
        )
    }

    if style not in templates:
        return "Invalid style selected"

    if style == "interview":
        return templates[style].format(topic=topic)

    return templates[style].format(topic=topic, audience=audience, tone=tone)


print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %%
# Task 7: Template Reusability Test

reusable_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

topics = ["AI", "Python", "Data Science", "Machine Learning", "Deep Learning"]

for t in topics:
    print(reusable_template.format(topic=t))
# Out:
# Explain AI in simple terms
# Explain Python in simple terms
# Explain Data Science in simple terms
# Explain Machine Learning in simple terms
# Explain Deep Learning in simple terms

# %%
# Final Pipeline Demo

topic = "Neural Networks"
audience = "beginner"
tone = "fun"
style = "teaching"

print(generate_prompt(topic, audience, tone, style))
# Out:
# Explain Neural Networks for beginner in a fun teaching style
